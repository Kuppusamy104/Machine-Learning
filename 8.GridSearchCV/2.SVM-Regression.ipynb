# %%
#To prdict the insurence charges using GridSearchCV for SVM with diff setting

# %%
import pandas as pd
dataset = pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset[['sex_male','smoker_yes']] = dataset[['sex_male','smoker_yes']].astype(int) # Change the column dtype to int after applying get_dummies

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid= {'kernel':['linear','rbf','sigmoid'],
             'C':[10,100,1000,2000,3000], 'gamma':['auto','scale']}

grid= GridSearchCV(SVR(), param_grid, refit= True, verbose=3, n_jobs=-1)

grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.064189      0.001536         0.010616        0.001838      10
# 1        0.059230      0.004095         0.027766        0.003941      10
# 2        0.044982      0.003183         0.010444        0.003938      10
# 3        0.052270      0.004678         0.012460        0.002515      10
# 4        0.048174      0.004021         0.030500        0.006435      10
# 5        0.059118      0.004642         0.012314        0.003934      10
# 6        0.125634      0.024219         0.010154        0.003811     100
# 7        0.055527      0.004605         0.030218        0.001221     100
# 8        0.044770      0.002346         0.006845        0.002874     100
# 9        0.128185      0.026916         0.009543        0.005345     100
# 10       0.047189      0.007532         0.027455        0.003909     100
# 11       0.059845      0.003858         0.010344        0.003070     100
# 12       0.482597      0.055196         0.010224        0.003451    1000
# 13       0.084043      0.007169         0.026101        0.004878    1000
# 14       0.038604      0.004281         0.010274        0.001585    1000
# 15       0.488974      0.055354         0.008530        0.000760    1000
# 16       0.057489      0.002708         0.027291        0.002738    1000
# 17       0.056899      0.002466         0.012761        0.001162    1000
# 18       0.912515      0.115447         0.010322        0.002509    2000
# 19       0.102892      0.007189         0.026395        0.004286    2000
# 20       0.056101      0.018037         0.008511        0.002431    2000
# 21       0.885909      0.099775         0.010413        0.002440    2000
# 22       0.071824      0.013601         0.029033        0.003311    2000
# 23       0.065004      0.004774         0.015452        0.001230    2000
# 24       1.521130      0.701688         0.007832        0.002859    3000
# 25       0.125621      0.009358         0.028587        0.004576    3000
# 26       0.051387      0.004243         0.009967        0.004167    3000
# 27       1.463426      0.598442         0.006608        0.004259    3000
# 28       0.061046      0.004900         0.024522        0.003662    3000
# 29       0.055603      0.004961         0.013329        0.004151    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto      sigmoid
# 3        scale       linear
# 4        scale          rbf
# 5        scale      sigmoid
# 6         auto       linear
# 7         auto          rbf
# 8         auto      sigmoid
# 9        scale       linear
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto          rbf
# 14        auto      sigmoid
# 15       scale       linear
# 16       scale          rbf
# 17       scale      sigmoid
# 18        auto       linear
# 19        auto          rbf
# 20        auto      sigmoid
# 21       scale       linear
# 22       scale          rbf
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto      sigmoid
# 27       scale       linear
# 28       scale          rbf
# 29       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.099849
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.041899
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 3     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.099849
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.045477
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.042877
# 6     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.477795
# 7        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.040107
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 9    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.477795
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.158546
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.059561
# 12   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.592288
# 13      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.064434
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 15  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.592288
# 16     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.191422
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.141295
# 18   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.600340
# 19      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.041473
# 20  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 21  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.600340
# 22     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}          -0.188138
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -4.204699
# 24   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.600282
# 25      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}          -0.010838
# 26  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.041634
# 27  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0